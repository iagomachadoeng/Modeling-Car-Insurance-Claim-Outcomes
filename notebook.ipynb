# %% [markdown]
# <center><img src="car.jpg" alt="Parked car" width="400" height="300"></center>
#
# Insurance companies invest a lot of [time and money](https://www.accenture.com/_acnmedia/pdf-84/accenture-machine-leaning-insurance.pdf) into optimizing their pricing and accurately estimating the likelihood that customers will make a claim. In many countries insurance it is a legal requirement to have car insurance in order to drive a vehicle on public roads, so the market is very large!
#
# Knowing all of this, On the Road car insurance have requested your services in building a model to predict whether a customer will make a claim on their insurance during the policy period. As they have very little expertise and infrastructure for deploying and monitoring machine learning models, they've asked you to use simple Logistic Regression, identifying the single feature that results in the best performing model, as measured by accuracy.
#
# They have supplied you with their customer data as a csv file called `car_insurance.csv`, along with a table detailing the column names and descriptions below.

# %% [markdown]
# ## The dataset
#
# | Column | Description |
# |--------|-------------|
# | `id` | Unique client identifier |
# | `age` | Client's age: <br> <ul><li>`0`: 16-15</li><li>`1`: 26-39</li><li>`2`: 40-64</li><li>`3`: 65+</li></ul> |
# | `gender` | Client's gender: <br> <ul><li>`0`: Female</li><li>`1`: Male</li></ul> |
# | `driving_experience` | Years the client has been driving: <br> <ul><li>`0`: 0-9</li><li>`1`: 10-19</li><li>`2`: 20-29</li><li>`3`: 30+</li></ul> |
# | `education` | Client's level of education: <br> <ul><li>`0`: No education</li><li>`1`: High school</li><li>`2`: University</li></ul> |
# | `income` | Client's income level: <br> <ul><li>`0`: Poverty</li><li>`1`: Working class</li><li>`2`: Middle class</li><li>`3`: Upper class</li></ul> |
# | `credit_score` | Client's credit score (between zero and one) |
# | `vehicle_ownership` | Client's vehicle ownership status: <br><ul><li>`0`: Does not own their vehilce (paying off finance)</li><li>`1`: Owns their vehicle</li></ul> |
# | `vehcile_year` | Year of vehicle registration: <br><ul><li>`0`: Before 2015</li><li>`1`: 2015 or later</li></ul> |
# | `married` | Client's marital status: <br><ul><li>`0`: Not married</li><li>`1`: Married</li></ul> |
# | `children` | Client's number of children |
# | `postal_code` | Client's postal code |
# | `annual_mileage` | Number of miles driven by the client each year |
# | `vehicle_type` | Type of car: <br> <ul><li>`0`: Sedan</li><li>`1`: Sports car</li></ul> |
# | `speeding_violations` | Total number of speeding violations received by the client |
# | `duis` | Number of times the client has been caught driving under the influence of alcohol |
# | `past_accidents` | Total number of previous accidents the client has been involved in |
# | `outcome` | Whether the client made a claim on their car insurance (response variable): <br><ul><li>`0`: No claim</li><li>`1`: Made a claim</li></ul> |

# %%
# Import required modules
import pandas as pd
import numpy as np
from statsmodels.formula.api import logit

# Start coding!
df = pd.read_csv('car_insurance.csv')
df.head()
# Out:
#        id  age  gender  ... duis past_accidents outcome
# 0  569520    3       0  ...    0              0     0.0
# 1  750365    0       1  ...    0              0     1.0
# 2  199901    0       0  ...    0              0     0.0
# 3  478866    0       1  ...    0              0     0.0
# 4  731664    1       1  ...    0              1     1.0
#
# [5 rows x 18 columns]

# %%
df['driving_experience'].unique()
# Out:
# array(['0-9y', '10-19y', '20-29y', '30y+'], dtype=object)

# %%
df.replace({'0-9y': 0, '10-19y': 1, '20-29y': 2, '30y+': 3},inplace=True);

# %%
df['driving_experience'].unique()
# Out:
# array([0, 1, 2, 3])

# %%
df.replace(['none', 'high school', 'university'], [0, 1, 2], inplace=True);

# %%
df.replace(['poverty', 'working class', 'middle class', 'upper class'], [0, 1, 2, 3], inplace = True);

# %%
df.replace(['before 2015', 'after 2015'], [0, 1], inplace=True);

# %%
df.replace(['sedan', 'sports car'], [0, 1], inplace=True);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   10000 non-null  int64
#  1   age                  10000 non-null  int64
#  2   gender               10000 non-null  int64
#  3   driving_experience   10000 non-null  int64
#  4   education            10000 non-null  int64
#  5   income               10000 non-null  int64
#  6   credit_score         9018 non-null   float64
#  7   vehicle_ownership    10000 non-null  float64
#  8   vehicle_year         10000 non-null  int64
#  9   married              10000 non-null  float64
#  10  children             10000 non-null  float64
#  11  postal_code          10000 non-null  int64
#  12  annual_mileage       9043 non-null   float64
#  13  vehicle_type         10000 non-null  int64
#  14  speeding_violations  10000 non-null  int64
#  15  duis                 10000 non-null  int64
#  16  past_accidents       10000 non-null  int64
#  17  outcome              10000 non-null  float64
# dtypes: float64(6), int64(12)
# memory usage: 1.4 MB

# %% [markdown]
# Looking at null values on credit_score and annual_mileage

# %%
df[df['credit_score'].isna()]
# Out:
#           id  age  gender  ...  duis  past_accidents  outcome
# 17     24851    0       1  ...     0               0      1.0
# 23       217    0       1  ...     0               0      0.0
# 37    511757    2       0  ...     0               1      0.0
# 38    429947    3       1  ...     0               5      0.0
# 47    921097    2       0  ...     0               2      0.0
# ...      ...  ...     ...  ...   ...             ...      ...
# 9952  870405    2       0  ...     0               0      0.0
# 9967   27406    1       0  ...     0               0      0.0
# 9981  366048    1       1  ...     0               0      0.0
# 9985  595418    0       1  ...     0               0      0.0
# 9988  479789    1       1  ...     0               2      1.0
#
# [982 rows x 18 columns]

# %%
df[df['annual_mileage'].isna()]
# Out:
#           id  age  gender  ...  duis  past_accidents  outcome
# 13    569640    0       0  ...     0               0      0.0
# 15    906223    1       0  ...     0               0      0.0
# 16    517747    3       1  ...     2               1      0.0
# 18    104086    1       0  ...     0               0      1.0
# 58    123941    2       0  ...     0               0      0.0
# ...      ...  ...     ...  ...   ...             ...      ...
# 9959  163840    2       1  ...     1               2      1.0
# 9969  355304    2       1  ...     2               0      0.0
# 9977  794068    3       1  ...     0               0      0.0
# 9988  479789    1       1  ...     0               2      1.0
# 9996  910346    1       0  ...     0               0      0.0
#
# [957 rows x 18 columns]

# %% [markdown]
# At first try we'll considere credit_score and annual_mileage null as 0.

# %%
df.fillna(0, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   10000 non-null  int64
#  1   age                  10000 non-null  int64
#  2   gender               10000 non-null  int64
#  3   driving_experience   10000 non-null  int64
#  4   education            10000 non-null  int64
#  5   income               10000 non-null  int64
#  6   credit_score         10000 non-null  float64
#  7   vehicle_ownership    10000 non-null  float64
#  8   vehicle_year         10000 non-null  int64
#  9   married              10000 non-null  float64
#  10  children             10000 non-null  float64
#  11  postal_code          10000 non-null  int64
#  12  annual_mileage       10000 non-null  float64
#  13  vehicle_type         10000 non-null  int64
#  14  speeding_violations  10000 non-null  int64
#  15  duis                 10000 non-null  int64
#  16  past_accidents       10000 non-null  int64
#  17  outcome              10000 non-null  float64
# dtypes: float64(6), int64(12)
# memory usage: 1.4 MB

# %% [markdown]
# Looking for some correlation between columns to simplify the model

# %%
corr_metrics = df.corr()
corr_metrics.style.background_gradient()
# Out:
# <style type="text/css">
# #T_e5f3d_row0_col0, #T_e5f3d_row1_col1, #T_e5f3d_row2_col2, #T_e5f3d_row3_col3, #T_e5f3d_row4_col4, #T_e5f3d_row5_col5, #T_e5f3d_row6_col6, #T_e5f3d_row7_col7, #T_e5f3d_row8_col8, #T_e5f3d_row9_col9, #T_e5f3d_row10_col10, #T_e5f3d_row11_col11, #T_e5f3d_row12_col12, #T_e5f3d_row13_col13, #T_e5f3d_row14_col14, #T_e5f3d_row15_col15, #T_e5f3d_row16_col16, #T_e5f3d_row17_col17 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e5f3d_row0_col1, #T_e5f3d_row6_col10, #T_e5f3d_row9_col6 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_e5f3d_row0_col2 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_e5f3d_row0_col3, #T_e5f3d_row4_col14, #T_e5f3d_row4_col16, #T_e5f3d_row7_col6 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_e5f3d_row0_col4, #T_e5f3d_row13_col6, #T_e5f3d_row13_col15 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_e5f3d_row0_col5, #T_e5f3d_row15_col10 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_e5f3d_row0_col6 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_e5f3d_row0_col7 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_e5f3d_row0_col8, #T_e5f3d_row0_col9, #T_e5f3d_row2_col4, #T_e5f3d_row6_col15, #T_e5f3d_row11_col9, #T_e5f3d_row11_col10 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_e5f3d_row0_col10, #T_e5f3d_row0_col12, #T_e5f3d_row13_col8, #T_e5f3d_row13_col12 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_e5f3d_row0_col11, #T_e5f3d_row1_col11, #T_e5f3d_row3_col11, #T_e5f3d_row8_col11 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_e5f3d_row0_col13, #T_e5f3d_row7_col13, #T_e5f3d_row12_col2, #T_e5f3d_row17_col13 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_e5f3d_row0_col14, #T_e5f3d_row4_col15, #T_e5f3d_row7_col15, #T_e5f3d_row11_col8, #T_e5f3d_row12_col7, #T_e5f3d_row15_col4 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_e5f3d_row0_col15, #T_e5f3d_row6_col12, #T_e5f3d_row7_col12, #T_e5f3d_row15_col12 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_e5f3d_row0_col16, #T_e5f3d_row2_col15 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_e5f3d_row0_col17, #T_e5f3d_row9_col8, #T_e5f3d_row13_col3 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_e5f3d_row1_col0, #T_e5f3d_row2_col13, #T_e5f3d_row9_col0, #T_e5f3d_row12_col11, #T_e5f3d_row14_col13, #T_e5f3d_row17_col10 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_e5f3d_row1_col2, #T_e5f3d_row3_col2, #T_e5f3d_row5_col17, #T_e5f3d_row7_col2, #T_e5f3d_row9_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_e5f3d_row1_col3 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_e5f3d_row1_col4, #T_e5f3d_row6_col4, #T_e5f3d_row16_col15 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_e5f3d_row1_col5, #T_e5f3d_row14_col3 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_e5f3d_row1_col6, #T_e5f3d_row15_col5 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_e5f3d_row1_col7, #T_e5f3d_row8_col1 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_e5f3d_row1_col8, #T_e5f3d_row2_col16 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_e5f3d_row1_col9, #T_e5f3d_row10_col3 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_e5f3d_row1_col10, #T_e5f3d_row9_col3, #T_e5f3d_row14_col5 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_e5f3d_row1_col12 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_e5f3d_row1_col13, #T_e5f3d_row3_col0, #T_e5f3d_row3_col13, #T_e5f3d_row5_col13, #T_e5f3d_row6_col0, #T_e5f3d_row6_col13, #T_e5f3d_row7_col0, #T_e5f3d_row10_col13, #T_e5f3d_row11_col0, #T_e5f3d_row11_col13, #T_e5f3d_row13_col0, #T_e5f3d_row14_col0, #T_e5f3d_row16_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_e5f3d_row1_col14 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_e5f3d_row1_col15, #T_e5f3d_row9_col14, #T_e5f3d_row10_col14, #T_e5f3d_row10_col16, #T_e5f3d_row11_col17, #T_e5f3d_row12_col17 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_e5f3d_row1_col16 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_e5f3d_row1_col17, #T_e5f3d_row9_col13 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_e5f3d_row2_col0, #T_e5f3d_row3_col17, #T_e5f3d_row6_col2, #T_e5f3d_row8_col13, #T_e5f3d_row9_col12, #T_e5f3d_row12_col9, #T_e5f3d_row12_col10, #T_e5f3d_row16_col11, #T_e5f3d_row17_col0, #T_e5f3d_row17_col1, #T_e5f3d_row17_col3, #T_e5f3d_row17_col4, #T_e5f3d_row17_col5, #T_e5f3d_row17_col6, #T_e5f3d_row17_col7, #T_e5f3d_row17_col8, #T_e5f3d_row17_col14, #T_e5f3d_row17_col15, #T_e5f3d_row17_col16 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e5f3d_row2_col1, #T_e5f3d_row2_col5, #T_e5f3d_row8_col9, #T_e5f3d_row11_col1, #T_e5f3d_row11_col14 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_e5f3d_row2_col3, #T_e5f3d_row11_col3, #T_e5f3d_row13_col17, #T_e5f3d_row15_col7 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_e5f3d_row2_col6 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_e5f3d_row2_col7, #T_e5f3d_row10_col6, #T_e5f3d_row13_col7, #T_e5f3d_row14_col4 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_e5f3d_row2_col8, #T_e5f3d_row14_col2 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_e5f3d_row2_col9, #T_e5f3d_row13_col9 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_e5f3d_row2_col10, #T_e5f3d_row4_col17, #T_e5f3d_row12_col1, #T_e5f3d_row14_col11, #T_e5f3d_row15_col17 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_e5f3d_row2_col11, #T_e5f3d_row5_col12, #T_e5f3d_row6_col11, #T_e5f3d_row7_col11, #T_e5f3d_row12_col4, #T_e5f3d_row13_col11 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_e5f3d_row2_col12, #T_e5f3d_row6_col17, #T_e5f3d_row8_col15, #T_e5f3d_row12_col8, #T_e5f3d_row13_col10 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_e5f3d_row2_col14, #T_e5f3d_row4_col6, #T_e5f3d_row16_col9 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_e5f3d_row2_col17 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_e5f3d_row3_col1 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_e5f3d_row3_col4, #T_e5f3d_row8_col6, #T_e5f3d_row8_col16, #T_e5f3d_row11_col5 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_e5f3d_row3_col5 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_e5f3d_row3_col6 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_e5f3d_row3_col7 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_e5f3d_row3_col8 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_e5f3d_row3_col9, #T_e5f3d_row6_col7 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_e5f3d_row3_col10 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_e5f3d_row3_col12, #T_e5f3d_row14_col17, #T_e5f3d_row15_col11 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_e5f3d_row3_col14 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_e5f3d_row3_col15 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_e5f3d_row3_col16 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_e5f3d_row4_col0, #T_e5f3d_row8_col0, #T_e5f3d_row10_col12, #T_e5f3d_row17_col9 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_e5f3d_row4_col1 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_e5f3d_row4_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_e5f3d_row4_col3 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_e5f3d_row4_col5 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_e5f3d_row4_col7 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_e5f3d_row4_col8, #T_e5f3d_row14_col9, #T_e5f3d_row14_col10 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_e5f3d_row4_col9 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_e5f3d_row4_col10, #T_e5f3d_row7_col10, #T_e5f3d_row8_col14, #T_e5f3d_row10_col8, #T_e5f3d_row14_col8, #T_e5f3d_row15_col9 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_e5f3d_row4_col11, #T_e5f3d_row5_col11, #T_e5f3d_row10_col11, #T_e5f3d_row16_col17 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_e5f3d_row4_col12, #T_e5f3d_row11_col6, #T_e5f3d_row12_col16 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_e5f3d_row4_col13, #T_e5f3d_row12_col13, #T_e5f3d_row1

# %% [markdown]
# ### Splitting our data

# %%
from sklearn.model_selection import train_test_split

X = df.drop('outcome', axis=1)
y = df.outcome

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 10)

# %%
X.columns
# Out:
# Index(['id', 'age', 'gender', 'driving_experience', 'education', 'income',
#        'credit_score', 'vehicle_ownership', 'vehicle_year', 'married',
#        'children', 'postal_code', 'annual_mileage', 'vehicle_type',
#        'speeding_violations', 'duis', 'past_accidents'],
#       dtype='object')

# %%
X_train[[X.columns[0]]].values
# Out:
# array([[ 71781],
#        [ 15689],
#        [274700],
#        ...,
#        [205125],
#        [533665],
#        [390289]])

# %%
from sklearn.linear_model import LogisticRegression
feature = []
accuracy = []
for column in X.columns:
    clf = LogisticRegression(random_state = 10)
    clf.fit(X_train[[column]].values, y_train.values)
    clf.predict(X_test[[column]].values)
    feature.append(column)
    accuracy.append(clf.score(X_test[[column]].values, y_test))

print(best_feature, best_accuracy)
# Out:
# driving_experience 0.7804

# %%
features_df = pd.DataFrame(list(zip(feature, accuracy)), columns = ['feature', 'accuracy'])
features_df
# Out:
#                 feature  accuracy
# 0                    id    0.6868
# 1                   age    0.7784
# 2                gender    0.6868
# 3    driving_experience    0.7804
# 4             education    0.6868
# 5                income    0.7380
# 6          credit_score    0.6456
# 7     vehicle_ownership    0.7352
# 8          vehicle_year    0.6868
# 9               married    0.6868
# 10             children    0.6868
# 11          postal_code    0.6868
# 12       annual_mileage    0.6868
# 13         vehicle_type    0.6868
# 14  speeding_violations    0.6868
# 15                 duis    0.6868
# 16       past_accidents    0.6868

# %%
#best_feature_df[['best_accuracy']].values.max()
best_index = features_df['accuracy'].idxmax()
best_index
# Out:
# 3

# %%
best_feature = features_df.iloc[best_index,0]
best_accuracy = features_df.iloc[best_index,1]

best_feature_df = pd.DataFrame([[best_feature, best_accuracy]], columns = ['best_feature', 'best_accuracy'])
best_feature_df
# Out:
#          best_feature  best_accuracy
# 0  driving_experience         0.7804
